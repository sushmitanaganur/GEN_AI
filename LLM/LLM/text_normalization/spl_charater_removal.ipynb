# %%
with open("data.txt","r") as file:
    data=file.read()
    for char in data:
        if  not char .isalnum() or  not ord(char)==32:
            data = data.replace(char,'')
            print(data)
            #print()
print(data)
# Out:
# pythonisobjectorientedhighleveldynamically
# typedscriptinglanguageaswellasprogramminglanguage
# pythonisobjectorientedhighleveldynamically
# typedscriptinglanguageaswellasprogramminglanguage
# ythonisobjectorientedhighleveldynamically
# tyedscritinglanguageaswellasrogramminglanguage
# thonisobjectorientedhighleveldnamicall
# tedscritinglanguageaswellasrogramminglanguage
# honisobjecorienedhighleveldnamicall
# edscriinglanguageaswellasrogramminglanguage
# onisobjecorienedigleveldnamicall
# edscriinglanguageaswellasrogramminglanguage
# nisbjecrienedigleveldnamicall
# edscriinglanguageaswellasrgramminglanguage
# isbjecrieedigleveldamicall
# edscriiglaguageaswellasrgrammiglaguage
# isbjecrieedigleveldamicall
# edscriiglaguageaswellasrgrammiglaguage
# sbjecreedgleveldamcall
# edscrglaguageaswellasrgrammglaguage
# bjecreedgleveldamcall
# edcrglaguageawellargrammglaguage
# bjecreedgleveldamcall
# edcrglaguageawellargrammglaguage
# bjecreedgleveldamcall
# edcrglaguageawellargrammglaguage
# ...
