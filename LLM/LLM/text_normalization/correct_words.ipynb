# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\Users\sushm\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.20.0)
# Requirement already satisfied: nltk>=3.9 in c:\Users\sushm\AppData\Local\Programs\Python\Python314\Lib\site-packages (from textblob) (3.10.0)
# Requirement already satisfied: defusedxml in c:\Users\sushm\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.9->textblob) (0.7.1)
# Requirement already satisfied: click in c:\Users\sushm\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in c:\Users\sushm\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\Users\sushm\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.9->textblob) (2026.7.10)
# Requirement already satisfied: tqdm in c:\Users\sushm\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.9->textblob) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\sushm\AppData\Roaming\Python\Python314\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# %%
text='corrting the word for txt normalization'
text1='corect the wods for txt normaliation'

corrected_words=TextBlob(text).correct
print(corrected_words,type(corrected_words))
# Out:
# <bound method BaseBlob.correct of TextBlob("corrting the word for txt normalization")> <class 'method'>
