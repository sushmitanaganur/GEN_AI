# %%
pip install contractions
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import contractions

# %%
s1="I'm a smart girl"
s2=" idk btw ASAP i'll try to complete this task"
contractions.fix(s1)
#contractions.fix(s2)
# Out:
# 'I am a smart girl'

# %%
contractions.fix(s2)
# Out:
# ' i do not know by the way AS SOON AS POSSIBLE i will try to complete this task'
