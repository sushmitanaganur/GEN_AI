# %%
pip install emoj
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement emoj (from versions: none)
# ERROR: No matching distribution found for emoj

# %%
import emoji

# %%
s=" hello 😒🙌😁💕😘"
emoji.demojize(s)
# Out:
# ' hello :unamused_face::raising_hands::beaming_face_with_smiling_eyes::two_hearts::face_blowing_a_kiss:'
