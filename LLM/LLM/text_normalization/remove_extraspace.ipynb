# %%
s1=" remove   extra space  "
s1.split()
" ".join(s1.split())
# Out:
# 'remove extra space'

# %%
with open('data.txt','r') as file:
    data=file.read()
    words=data.split()
    data=''.join(words)
print(data)
# Out:
# pythonisobjectorientedhighleveldynamicallytypedscriptinglanguageaswellasprogramminglanguage
